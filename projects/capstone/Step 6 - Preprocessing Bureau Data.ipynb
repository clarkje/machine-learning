# %% [markdown]
# ##  Data Preprocessing
#
# Step 2:
#
# Perform various transformations on our data as required for efficient and effective processing by Machine Learning algorithms based on the type and needs of individual features, identified through the data explorations performed in Step 1 - Data Exploration - Application Data.
#
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display # Allows the use of display() for DataFrames
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from sklearn.preprocessing import LabelBinarizer

# Show all of the data in a dataframe
pd.set_option('display.max_columns', None)

# %%
# Training Set
application_train = pd.read_csv('data/tmp/application_train_bureau_data_merged.csv', index_col=0)
application_test = pd.read_csv('data/tmp/application_test_bureau_data_merged.csv', index_col=0)
print("Loaded Training Set: {0} rows {1} cols".format(application_train.shape[0], application_train.shape[1]))
print("Loaded Testing Set: {0} rows {1} cols".format(application_test.shape[0], application_test.shape[1]))
# Out:
# Loaded Training Set: 307511 rows 315 cols
# Loaded Testing Set: 48744 rows 314 cols

# %%
target_train = application_train['TARGET']
application_train_SK_ID_CURR = application_train['SK_ID_CURR']
application_train = application_train.drop('SK_ID_CURR', axis=1)
application_train = application_train.drop('TARGET', axis=1)

application_test_SK_ID_CURR = application_test['SK_ID_CURR']
application_test = application_test.drop('SK_ID_CURR', axis=1)

# %%
display(application_train.head())
display(application_test.head())
# Out:
#    AMT_ANNUITY  AMT_CREDIT  AMT_GOODS_PRICE  AMT_INCOME_TOTAL  \
# 0    -0.166065   -0.478095        -0.505662          0.142129
# 1     0.592710    1.725450         1.600480          0.426792
# 2    -1.404507   -1.152888        -1.090025         -0.427196
# 3     0.177929   -0.711430        -0.651753         -0.142533
# 4    -0.361658   -0.213734        -0.067390         -0.199466
#
#    AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_HOUR  \
# 0                  -0.058766                   -0.070987
# 1                  -0.058766                   -0.070987
# 2                  -0.058766                   -0.070987
# 3                  -0.058766                   -0.070987
# 4                  -0.058766                   -0.070987
#
#    AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# 0                  -0.269947                   -0.30862
# 1                  -0.269947                   -0.30862
# 2                  -0.269947                   -0.30862
# 3                  -0.269947                   -0.30862
# 4                  -0.269947                   -0.30862
#
#    AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_YEAR  APARTMENTS_AVG  \
# 0                   -0.155837                   -0.346719       -0.345180
# 1                   -0.155837                   -0.885565        0.396431
# 2                   -0.155837                   -0.885565       -0.602452
# 3                   -0.155837                   -0.885565       -0.602452
# 4                   -0.155837                   -0.885565       -0.602452
#
#    APARTMENTS_MEDI  APARTMENTS_MODE  BASEMENTAREA_AVG  BASEMENTAREA_MEDI  \
# 0        -0.342055        -0.327407          0.003066           0.006034
# 1         0.401242         0.380977          0.236003           0.239930
# 2        -0.600864        -0.593050         -0.534146          -0.533388
# 3        -0.600864        -0.593050         -0.534146          -0.533388
# 4        -0.600864        -0.593050         -0.534146          -0.533388
#
#    BASEMENTAREA_MODE  BOOL_FLAG_EMAIL  BOOL_FLAG_EMP_PHONE  BOOL_FLAG_OWN_CAR  \
# 0           0.028603        -0.245215             0.468697          -0.717914
# 1           0.252119        -0.245215             0.468697          -0.717914
# 2          -0.523697        -0.245215             0.468697           1.392925
# 3          -0.523697        -0.245215             0.468697          -0.717914
# 4          -0.523697        -0.245215             0.468697          -0.717914
#
#    BOOL_FLAG_OWN_REALTY  BOOL_FLAG_PHONE  BOOL_FLAG_WORK_PHONE  CNT_CHILDREN  \
# 0              0.664531         1.599337             -0.499013     -0.577538
# 1             -1.504820         1.599337             -0.499013     -0.577538
# 2              0.664531         1.599337              2.003956     -0.577538
# 2                   -0.296432                   -0.266452
# 3                   -0.296432                   -0.266452
# 4                   -0.296432                   -0.266452
#
#    HOUR_APPR_PROCESS_START_17  HOUR_APPR_PROCESS_START_18  \
# 0                   -0.225656                   -0.174123
# 1                   -0.225656                   -0.174123
# 2                   -0.225656                   -0.174123
# 3                    4.431515                   -0.174123
# 4                   -0.225656                   -0.174123
#
#    HOUR_APPR_PROCESS_START_19  HOUR_APPR_PROCESS_START_2  \
# 0                    -0.11257                  -0.031509
# 1                    -0.11257                  -0.031509
# 2                    -0.11257                  -0.031509
# 3                    -0.11257                  -0.031509
# 4                    -0.11257                  -0.031509
#
#    HOUR_APPR_PROCESS_START_20  HOUR_APPR_PROCESS_START_21  \
# 0                   -0.062486                   -0.036315
# 1                   -0.062486                   -0.036315
# 2                   -0.062486                   -0.036315
# 3                   -0.062486                   -0.036315
# 4                   -0.062486                   -0.036315
#
#    HOUR_APPR_PROCESS_START_22  HOUR_APPR_PROCESS_START_23  \
# 0                   -0.022091                   -0.011548
# 1                   -0.022091                   -0.011548
# 2                   -0.022091                   -0.011548
# 3                   -0.022091                   -0.011548
# 4                   -0.022091                   -0.011548
#
#    HOUR_APPR_PROCESS_START_3  HOUR_APPR_PROCESS_START_4  \
# 0                  -0.063371                  -0.082723
# 1                  -0.063371                  -0.082723
# 2                  -0.063371                  -0.082723
# 3                  -0.063371                  -0.082723
# 4                  -0.063371                  -0.082723
#
#    HOUR_APPR_PROCESS_START_5  HOUR_APPR_PROCESS_START_6  \
# 0                  -0.109417                   -0.13916
# 1                  -0.109417                   -0.13916
# 2                  -0.109417                   -0.13916
# 3                  -0.109417                   -0.13916
# 4                  -0.109417                   -0.13916
#
#    HOUR_APPR_PROCESS_START_7  HOUR_APPR_PROCESS_START_8  \
# 0                  -0.174934                  -0.227457
# 1                  -0.174934                  -0.227457
# 2                  -0.174934                  -0.227457
# 3                  -0.174934                  -0.227457
# 4                  -0.174934                  -0.227457
#
#    HOUR_APPR_PROCESS_START_9  HOUSETYPE_MODE_not specified  \
# 0                  -0.312659                     -1.536135
# 1                  -0.312659                     -1.536135
# 2                   3.198372                      0.650984
# 3                  -0.312659                      0.650984
# 4                  -0.312659                      0.650984
#
#    HOUSETYPE_MODE_org spec account  HOUSETYPE_MODE_reg oper account  \
# 0                        -0.136428                         1.779079
# 1                        -0.136428                         1.779079
# 2                        -0.136428                        -0.562089
# 3                        -0.136428                        -0.562089
# 4                        -0.136428                        -0.562089
#
#    HOUSETYPE_MODE_reg oper spec account  LANDAREA_AVG  LANDAREA_MEDI  \
# 0                             -0.202211      0.162782       0.165022
# 1                             -0.202211     -0.228092      -0.227585
# 2                             -0.202211     -0.440702      -0.440853
# 3                             -0.202211     -0.440702      -0.440853
# 4                             -0.202211     -0.440702      -0.440853
#
#    LANDAREA_MODE  LIVE_CITY_NOT_WORK_CITY  LIVE_REGION_NOT_WORK_REGION  \
# 0       0.185154                -0.467814                    -0.205869
# 1      -0.222405                -0.467814                    -0.205869
# 2      -0.431913                -0.467814                    -0.205869
# 3      -0.431913                -0.467814                    -0.205869
#
#    NAME_INCOME_TYPE_Unemployed  NAME_INCOME_TYPE_Working  \
# 0                    -0.008459                  0.967876
# 1                    -0.008459                 -1.033190
# 2                    -0.008459                  0.967876
# 3                    -0.008459                  0.967876
# 4                    -0.008459                  0.967876
#
#    NAME_TYPE_SUITE_Children  NAME_TYPE_SUITE_Family  \
# 0                 -0.103625               -0.387514
# 1                 -0.103625                2.580551
# 2                 -0.103625               -0.387514
# 3                 -0.103625               -0.387514
# 4                 -0.103625               -0.387514
#
#    NAME_TYPE_SUITE_Group of people  NAME_TYPE_SUITE_Other_A  \
# 0                        -0.029699                -0.053142
# 1                        -0.029699                -0.053142
# 2                        -0.029699                -0.053142
# 3                        -0.029699                -0.053142
# 4                        -0.029699                -0.053142
#
#    NAME_TYPE_SUITE_Other_B  NAME_TYPE_SUITE_Spouse, partner  \
# 0                -0.076087                        -0.195944
# 1                -0.076087                        -0.195944
# 2                -0.076087                        -0.195944
# 3                -0.076087                        -0.195944
# 4                -0.076087                        -0.195944
#
#    NAME_TYPE_SUITE_Unaccompanied  NONLIVINGAPARTMENTS_AVG  \
# 0                       0.487175                -0.100846
# 1                      -2.052651                 0.045223
# 2                       0.487175                -0.100846
# 3                       0.487175                -0.100846
# 4                       0.487175                -0.100846
#
#    NONLIVINGAPARTMENTS_MEDI  NONLIVINGAPARTMENTS_MODE  NONLIVINGAREA_AVG  \
# 0                 -0.099729                 -0.095487          -0.261343
# 1                  0.047355                 -0.095487          -0.059838
# 2                 -0.099729                 -0.095487          -0.261343
# 3                 -0.099729                 -0.095487          -0.261343
# 4                 -0.099729                 -0.095487          -0.261343
#
#    NONLIVINGAREA_MEDI  NONLIVINGAREA_MODE  OBS_30_CNT_SOCIAL_CIRCLE  \
# 0           -0.258124           -0.247602                  0.242861
# 1           -0.054163           -0.247602                 -0.174085
# 2           -0.258124           -0.247602                 -0.591031
# 3           -0.258124           -0.247602                  0.242861
# 4           -0.258124           -0.247602                 -0.591031
#
#    OBS_60_CNT_SOCIAL_CIRCLE  OCCUPATION_TYPE_Accountants  \
# 0                  0.252132                    -0.181557
# 1                 -0.168527                    -0.181557
# 2                 -0.589187                    -0.181557
# 3                  0.252132                    -0.181557
# 4                 -0.589187                    -0.181557
#
#    OCCUPATION_TYPE_Cleaning staff  OCCUPATION_TYPE_Cooking staff  \
# 0                        -0.12395                      -0.140418
# 1                        -0.12395                      -0.140418
# 2                        -0.12395                      -0.140418
# 3                        -0.12395                      -0.140418
# 4                        -0.12395                      -0.140418
#
#    OCCUPATION_TYPE_Core staff  OCCUPATION_TYPE_Drivers  \
# 0                   -0.313823                -0.253753
# 1                    3.186507                -0.253753
# 2                   -0.313823                -0.253753
# 3                   -0.313823                -0.253753
# 4                    3.186507                -0.253753
#
#    OCCUPATION_TYPE_HR staff  OCCUPATION_TYPE_High skill tech staff  \
# 0                 -0.042827                              -0.196033
# 1                 -0.042827                              -0.196033
# 2                 -0.042827                              -0.196033
# 3                 -0.042827                              -0.196033
# 4                 -0.042827                              -0.196033
#
#    OCCUPATION_TYPE_IT staff  OCCUPATION_TYPE_Laborers  \
# 0                 -0.041394                  2.138285
# 1                 -0.041394                 -0.467664
# 2                 -0.041394                  2.138285
# 3                 -0.041394                  2.138285
# 4                 -0.041394                 -0.467664
#
#    OCCUPATION_TYPE_Low-skill Laborers  OCCUPATION_TYPE_Managers  \
# 0                           -0.082782                  -0.27329
# 1                           -0.082782                  -0.27329
# 2                           -0.082782                  -0.27329
# 3                           -0.082782                  -0.27329
# 4                           -0.082782                  -0.27329
#
#    OCCUPATION_TYPE_Medicine staff  OCCUPATION_TYPE_Private service staff  \
# 0                        -0.16898                              -0.093269
# 1                        -0.16898                              -0.093269
# 2                        -0.16898                              -0.093269
# 3                        -0.16898                              -0.093269
# 4                        -0.16898                              -0.093269
#
#    OCCUPATION_TYPE_Realty agents  OCCUPATION_TYPE_Sales staff  \
# 0                      -0.049479                    -0.341411
# 1                      -0.049479                    -0.341411
# 2                      -0.049479                    -0.341411
# 3                      -0.049479                    -0.341411
# 4                      -0.049479                    -0.341411
#
#    OCCUPATION_TYPE_Secretaries  OCCUPATION_TYPE_Security staff  \
# 0                    -0.065283                       -0.149481
# 1                    -0.065283                       -0.149481
# 2                    -0.065283                       -0.149481
# 3                    -0.065283                       -0.149481
# 4                    -0.065283                       -0.149481
#
#    OCCUPATION_TYPE_Waiters/barmen staff  ORGANIZATION_TYPE_Advertising  \
# 0                             -0.066354                      -0.037377
# 1                             -0.066354                      -0.037377
# 2                             -0.066354                      -0.037377
# 3                             -0.066354                      -0.037377
# 4                             -0.066354                      -0.037377
#
#    ORGANIZATION_TYPE_Agriculture  ORGANIZATION_TYPE_Bank  \
# 0
ALLSMATERIAL_MODE_Mixed  WALLSMATERIAL_MODE_Monolithic  \
# 0                 -0.086733                      -0.076281
# 1                 -0.086733                      -0.076281
# 2                 -0.086733                      -0.076281
# 3                 -0.086733                      -0.076281
# 4                 -0.086733                      -0.076281
#
#    WALLSMATERIAL_MODE_Others  WALLSMATERIAL_MODE_Panel  \
# 0                  -0.072886                 -0.522963
# 1                  -0.072886                 -0.522963
# 2                  -0.072886                 -0.522963
# 3                  -0.072886                 -0.522963
# 4                  -0.072886                 -0.522963
#
#    WALLSMATERIAL_MODE_Stone, brick  WALLSMATERIAL_MODE_Wooden  \
# 0                         1.935056                  -0.133215
# 1                        -0.516781                  -0.133215
# 2                        -0.516781                  -0.133215
# 3                        -0.516781                  -0.133215
# 4                        -0.516781                  -0.133215
#
#    WALLSMATERIAL_MODE_not specified  WEEKDAY_APPR_PROCESS_START_FRIDAY  \
# 0                         -1.016959                          -0.442421
# 1                         -1.016959                          -0.442421
# 2                          0.983323                          -0.442421
# 3                          0.983323                          -0.442421
# 4                          0.983323                          -0.442421
#
#    WEEKDAY_APPR_PROCESS_START_MONDAY  WEEKDAY_APPR_PROCESS_START_SATURDAY  \
# 0                          -0.444395                            -0.351712
# 1                           2.250251                            -0.351712
# 2                           2.250251                            -0.351712
# 3                          -0.444395                            -0.351712
# 4                          -0.444395                            -0.351712
#
#    WEEKDAY_APPR_PROCESS_START_SUNDAY  WEEKDAY_APPR_PROCESS_START_THURSDAY  \
# 0                          -0.235673                            -0.443749
# 1                          -0.235673                            -0.443749
# 2                          -0.235673                            -0.443749
# 3                          -0.235673                            -0.443749
# 4                          -0.235673                             2.253525
#
#    WEEKDAY_APPR_PROCESS_START_TUESDAY  WEEKDAY_APPR_PROCESS_START_WEDNESDAY  \
# 0                           -0.461015                              2.218375
# 1                           -0.461015                             -0.450780
# 2                           -0.461015                             -0.450780
# 3                           -0.461015                              2.218375
# 4                           -0.461015                             -0.450780
#
#    YEARS_BEGINEXPLUATATION_AVG  YEARS_BEGINEXPLUATATION_MEDI  \
# 0                     0.960978                      0.960861
# 1                     0.987275                      0.987155
# 2                    -1.020852                     -1.020765
# 3                    -1.020852                     -1.020765
# 4                    -1.020852                     -1.020765
#
#    YEARS_BEGINEXPLUATATION_MODE  YEARS_BUILD_AVG  YEARS_BUILD_MEDI  \
# 0                      0.961652         1.016443          1.023576
# 1                      0.987948         1.505968          1.504599
# 2                     -1.020127        -0.698001         -0.698343
# 3                     -1.020127        -0.698001         -0.698343
# 4                     -1.020127        -0.698001         -0.698343
#
#    YEARS_BUILD_MODE  PER_CREDIT_INCOME  PER_GOODS_CREDIT  PER_ANNUITY_INCOME  \
# 0          1.042389           0.159961          0.018189            0.141793
# 1          1.508933          -0.174450         -0.168532            0.276183
# 2         -0.698841           0.072629          0.003323            0.082723
# 3         -0.698841           0.091853          0.004154            0.039259
# 4         -0.698841           0.046191         -0.010885            0.063702
#
#    NUM_BUREAU_REPORTS  SUM_BUREAU_BALANCES  SUM_CREDIT_CURRENCY_CODE_0  \
# 0                 8.0                110.0                         8.0
# 1                 NaN                  NaN                         NaN
# 2                 NaN                  NaN                         NaN
# 3                 NaN                  NaN                         NaN
# 4                 NaN                  NaN                         NaN
#
#    SUM_CREDIT_CURRENCY_CODE_1  SUM_CREDIT_CURRENCY_CODE_2  \
# 0                         0.0                         0.0
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    SUM_CREDIT_CURRENCY_CODE_3  SUM_CREDIT_ACTIVE_CODE_0  \
# 0                         0.0                       2.0
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
#    SUM_CREDIT_ACTIVE_CODE_1  SUM_CREDIT_ACTIVE_CODE_2  \
# 0                       0.0                       6.0
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
# ...
# 0                  -0.17257                   -0.103304
# 1                  -0.17257                   -0.103304
# 2                  -0.17257                   -0.103304
# 3                  -0.17257                   -0.103304
# 4                  -0.17257                   -0.103304
#
#    ORGANIZATION_TYPE_Security Ministries  ORGANIZATION_TYPE_Self-employed  \
# 0
WEEKDAY_APPR_PROCESS_START_FRIDAY  \
# 0                         -1.016959                          -0.442421
# 1                          0.983323                           2.260293
# 2                          0.983323                          -0.442421
# 3                         -1.016959                          -0.442421
# 4                          0.983323                           2.260293
#
#    WEEKDAY_APPR_PROCESS_START_MONDAY  WEEKDAY_APPR_PROCESS_START_SATURDAY  \
# 0                          -0.444395                            -0.351712
# 1                          -0.444395                            -0.351712
# 2                           2.250251                            -0.351712
# 3                          -0.444395                            -0.351712
# 4                          -0.444395                            -0.351712
#
#    WEEKDAY_APPR_PROCESS_START_SUNDAY  WEEKDAY_APPR_PROCESS_START_THURSDAY  \
# 0                          -0.235673                            -0.443749
# 1                          -0.235673                            -0.443749
# 2                          -0.235673                            -0.443749
# 3                          -0.235673                            -0.443749
# 4                          -0.235673                            -0.443749
#
#    WEEKDAY_APPR_PROCESS_START_TUESDAY  WEEKDAY_APPR_PROCESS_START_WEDNESDAY  \
# 0                            2.169126                             -0.450780
# 1                           -0.461015                             -0.450780
# 2                           -0.461015                             -0.450780
# 3                           -0.461015                              2.218375
# 4                           -0.461015                             -0.450780
#
#    YEARS_BEGINEXPLUATATION_AVG  YEARS_BEGINEXPLUATATION_MEDI  \
# 0                     0.963017                      0.962899
# 1                    -1.020852                     -1.020765
# 2                    -1.020852                     -1.020765
# 3                     1.011533                      1.011411
# 4                    -1.020852                     -1.020765
#
#    YEARS_BEGINEXPLUATATION_MODE  YEARS_BUILD_AVG  YEARS_BUILD_MEDI  \
# 0                      0.963691        -0.698001         -0.698343
# 1                     -1.020127        -0.698001         -0.698343
# 2                     -1.020127        -0.698001         -0.698343
# 3                      1.012206         1.957837          1.948663
# 4                     -1.020127        -0.698001         -0.698343
#
#    YEARS_BUILD_MODE  PER_CREDIT_INCOME  PER_GOODS_CREDIT  PER_ANNUITY_INCOME  \
# 0         -0.698841           1.959564          1.082492            3.134419
# 1         -0.698841           2.589443          0.995877            2.847896
# 2         -0.698841           2.667978          0.891096           -2.353927
# 3          1.939503          57.203297          1.404329          -19.562760
# 4         -0.698841           2.378808          0.836596            2.773216
#
#    NUM_BUREAU_REPORTS  SUM_BUREAU_BALANCES  SUM_CREDIT_CURRENCY_CODE_0  \
# 0                 NaN                  NaN                         NaN
# 1                 NaN                  NaN                         NaN
# 2                 NaN                  NaN                         NaN
# 3                 NaN                  NaN                         NaN
# 4                 NaN                  NaN                         NaN
#
#    SUM_CREDIT_CURRENCY_CODE_1  SUM_CREDIT_CURRENCY_CODE_2  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    SUM_CREDIT_CURRENCY_CODE_3  SUM_CREDIT_ACTIVE_CODE_0  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
#    SUM_CREDIT_ACTIVE_CODE_1  SUM_CREDIT_ACTIVE_CODE_2  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    SUM_CREDIT_ACTIVE_CODE_3  SUM_CREDIT_TYPE_CODE_0  SUM_CREDIT_TYPE_CODE_1  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
#
#    SUM_CREDIT_TYPE_CODE_2  SUM_CREDIT_TYPE_CODE_3  SUM_CREDIT_TYPE_CODE_4  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    SUM_CREDIT_TYPE_CODE_5  SUM_CREDIT_TYPE_CODE_6  SUM_CREDIT_TYPE_CODE_7  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    SUM_CREDIT_TYPE_CODE_8  SUM_CREDIT_TYPE_CODE_9  SUM_CREDIT_TYPE_CODE_10  \
# 0                     NaN                     NaN                      NaN
# 1                     NaN                     NaN                      NaN
# 2                     NaN                     NaN                      NaN
# 3                     NaN                     NaN                      NaN
# 4                     NaN                     NaN                      NaN
#
#    SUM_CREDIT_TYPE_CODE_11  SUM_CREDIT_TYPE_CODE_12  SUM_CREDIT_TYPE_CODE_13  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    SUM_CREDIT_TYPE_CODE_14  SUM_STATUS_0  SUM_STATUS_1  SUM_STATUS_2  \
# 0                      NaN           NaN           NaN           NaN
# 1                      NaN           NaN           NaN           NaN
# 2                      NaN           NaN           NaN           NaN
# 3                      NaN           NaN           NaN           NaN
# 4                      NaN           NaN           NaN           NaN
#
#    SUM_STATUS_3  SUM_STATUS_4  SUM_STATUS_5  SUM_STATUS_C  SUM_STATUS_X  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#    MED_DAYS_CREDIT  SUM_CREDIT_DAYS_OVERDUE  SUM_DAYS_CREDIT_ENDDATE  \
# 0              NaN                      NaN                      NaN
# 1              NaN                      NaN                      NaN
# 2              NaN                      NaN                      NaN
# 3              NaN                      NaN                      NaN
# 4              NaN                      NaN                      NaN
#
#    SUM_DAYS_ENDDATE_FACT  SUM_AMT_CREDIT_MAX_OVERDUE  SUM_CNT_CREDIT_PROLONG  \
# 0                    NaN                         NaN                     NaN
# 1                    NaN                         NaN                     NaN
# 2                    NaN                         NaN                     NaN
# 3                    NaN                         NaN                     NaN
# 4                    NaN                         NaN                     NaN
#
#    SUM_AMT_CREDIT_SUM  SUM_AMT_CREDIT_SUM_DEBT  SUM_AMT_CREDIT_SUM_LIMIT  \
# 0                 NaN                      NaN                       NaN
# 1                 NaN                      NaN                       NaN
# 2                 NaN                      NaN                       NaN
# 3                 NaN                      NaN                       NaN
# 4                 NaN                      NaN                       NaN
#
#    SUM_DAYS_CREDIT_UPDATE
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
# Load the list of features indentified in the exploration step which need preprocessing
#non_numeric_features = pd.read_csv('data/tmp/bureau_non_numeric_features.csv', header=0, index_col=0, names=["feature"])
non_numeric_features = []
numeric_features = pd.read_csv('data/tmp/bureau_numeric_features.csv', header=0, index_col=0, names=["feature"])
#string_to_bool_features = pd.read_csv('data/tmp/bureau_string_to_bool.csv', header=0, index_col=0, names=["feature"])
string_to_bool_features = []
log_transform_features = pd.read_csv('data/tmp/bureau_log_transform.csv', header=0, index_col=0, names=["feature"])

# %%
display(numeric_features.head())
# Out:
#                       feature
# 0          NUM_BUREAU_REPORTS
# 1         SUM_BUREAU_BALANCES
# 2  SUM_CREDIT_CURRENCY_CODE_0
# 3  SUM_CREDIT_CURRENCY_CODE_1
# 4  SUM_CREDIT_CURRENCY_CODE_2

# %%
print("Non-Numeric {0}, Numeric {1}, Bool {2}, Log Transform {3}".format(\
        len(non_numeric_features), len(numeric_features), \
        len(string_to_bool_features), len(log_transform_features)))
# Out:
# Non-Numeric 0, Numeric 42, Bool 0, Log Transform 1

# %%
'''
Scales a list of numeric features to a range of [0 .. 1] without changing the distribution of the data.  
Accepts a List of column names.  Returns a new dataFrame.
''' 
def scale_features(dataFrame, featureList): 
    dataFrame_transform = pd.DataFrame(data = dataFrame)
    dataFrame_transform[featureList] = scaler.fit_transform(dataFrame_transform[featureList])
    return dataFrame_transform

# %%
''' 
Applies an in-place transformation that converts a Y/N field to binary 1/0
'''
def make_bool(dataFrame, featureName): 
    
    lb = LabelBinarizer()
    bool_name = "BOOL_{0}".format(featureName)    
    dataFrame[bool_name] = lb.fit_transform(dataFrame[featureName])
    
    # This seems to work more consistently than df.drop
    # From: https://stackoverflow.com/questions/43838198/df-drop-is-not-working
    del(dataFrame[featureName])    
    #result = dataFrame.drop(featureName, axis=1) 
    
    return dataFrame

# %%
''' 
Applies an in-place transformation that converts NaN, Inf and -Inf to numeric values
'''
def make_numeric(dataFrame, featureName): 
        
    return np.nan_to_num(dataFrame[featureName])

# %%
'''
Applies an in-place abs() to numeric features
'''
def abs_transform(dataFrame, featureName):     
    
    transformed = dataFrame[featureName].apply(lambda x: abs(x))
        
    dataFrame[featureName] = transformed
    
    return dataFrame

# %%
'''
Applies an in-place log transformation to numeric features
'''
def log_transform(dataFrame, featureName):     
    
    transformed = dataFrame[featureName].apply(lambda x: np.log(x + 1))
    
    transformed_name = "LOG_{0}".format(featureName)

    print("Transformed Name: {0}".format(transformed_name))
    
    dataFrame[transformed_name] = transformed

    # This seems to work more consistently than df.drop
    # From: https://stackoverflow.com/questions/43838198/df-drop-is-not-working
    del(dataFrame[featureName])
    #result = dataFrame.drop(featureName, axis=1)
    
    return dataFrame

# %%
'''
Applies an in-place transformation that offsets all values in a column by the minimum value in the column
'''

def find_offset(dataFrames, featureName): 
    
    offset = 0
    
    for df in dataFrames: 
        if (np.min(df[featureName]) < offset): 
            offset = np.min(df[featureName])

    return abs(offset) + 1
            
            
def offset_negative_values(dataFrame, featureName, offset): 
    print("Offsetting Feature {0} by {1}".format(featureName, offset))
    return dataFrame[featureName].apply(lambda x: (x + offset)), offset

# %%
# Tukey's Method for detecting outliers
# Adapted from the customer segments exercise

def return_outliers(dataFrame, featureList): 
    
    outliers = []
    count = 0
    
    frame_stats = []

    for feature_count, feature in enumerate(featureList): 

        feature_stats = {}

        dataFrame[feature] = np.nan_to_num(dataFrame[feature])

        # Calculate Q1 (25th percentile of the data) for the given feature
        Q1 = np.percentile(dataFrame[feature], 25)

        # Calculate Q3 (75th percentile of the data) for the given feature
        Q3 = np.percentile(dataFrame[feature], 75)

        # TODO: Use the interquartile range to calculate an outlier step
        step = (Q3 - Q1) * 1.5

        feature_stats['Q1_percentile'] = Q1
        feature_stats['Q3_percentile'] = Q3
        feature_stats['step'] = step
        feature_stats['feature'] = feature
        feature_stats['feature_min'] = np.min(dataFrame[feature])
        feature_stats['feature_max'] = np.max(dataFrame[feature])
        feature_stats['feature_median'] = np.median(dataFrame[feature])

        # Calculate the median of the interquartile range
        # TODO: This just sounds good intuitively.  It's probably worth researching the actual best practice.
        feature_stats['IQ_median'] = np.median([Q1, Q3])

        # Save a list of the outliers
        feature_stats['outliers'] = dataFrame.index[~((dataFrame[feature] >= Q1 - step) & (dataFrame[feature] <= Q3 + step))]

        # Just keep a count of the number of fields we identified
        count += len(feature_stats['outliers'])

        frame_stats.append(feature_stats)

    outliers.append(frame_stats)   
        
    print("Total Outliers Identified: {0}".format(count))
        
    return outliers

# %%
def replace_outliers(dataFrame, outliers):
    
    count = 0
    
    for ol in outliers: 

        for feature_count, feature in enumerate(ol): 

            # Some features have infrequent but meaningful values, and averaging to 0 would be a problem.
            # We'll just skip these when they come up.
            # example: "How many credit applications were made in the past hour?" 
            if(feature['IQ_median'] >= 1): 

                featureName = feature['feature']
                print("Processing feature {0}".format(featureName))

                '''
                # Perhaps we can one-shot these?
                median = feature['IQ_median']

                try: 
                    frame.iloc[feature_count, feature['outliers']] = median

                    #df.feature_a.iloc[[1, 3, 15]] = 88

                    print("Replacing {2} values at Feature {0} with {1}".format(featureName, median, len(feature['outliers'])))

                except Exception as e: 
                     print("Skipped Feature {0} because {1}".format(featureName, str(e)))

                '''

                for out_index in feature['outliers']: 

                    try: 
                        median = feature['IQ_median']
                        value = dataFrame.iloc[feature_count, out_index:out_index]

                        # Correct way to set value on the dataframe
                        # Per https://pandas.pydata.org/pandas-docs/version/0.21/indexing.html#indexing-label

                        dataFrame.iloc[feature_count, out_index:out_index] = median

                        #print("Replacing value {2} at index {0} with {1}".format(out_index, median, value))
                    except Exception as e:
                        print("Skipped Record at {1} Index {0} because {2}".format(out_index, featureName, str(e)))

                    # Keep track of the number of values we modified
                    count += 1

    print("Total Outliers Modified: {0}".format(count))
    return dataFrame

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Log Transform Skewed Numeric Features

# %%
application_train = abs_transform(application_train, 'SUM_DAYS_ENDDATE_FACT')
application_test = abs_transform(application_test, 'SUM_DAYS_ENDDATE_FACT')

application_train = abs_transform(application_train, 'SUM_DAYS_CREDIT_ENDDATE')
application_test = abs_transform(application_test, 'SUM_DAYS_CREDIT_ENDDATE')

application_train = abs_transform(application_train, 'SUM_DAYS_CREDIT_UPDATE')
application_test = abs_transform(application_test, 'SUM_DAYS_CREDIT_UPDATE')

# %%
''' 
# Skipping Log transformations for the time being... 

# Ensure all values are numeric, then log transform them
for feature in log_transform_features['feature']: 
        application_train[feature] = make_numeric(application_train, feature)
    
        print("Performing Log Transformations on: {0}".format(feature))
        application_train = log_transform(application_train, feature)
'''
# Out:
# ' \n# Skipping Log transformations for the time being... \n\n# Ensure all values are numeric, then log transform them\nfor feature in log_transform_features[\'feature\']: \n        application_train[feature] = make_numeric(application_train, feature)\n    \n        print("Performing Log Transformations on: {0}".format(feature))\n        application_train = log_transform(application_train, feature)\n'

# %% [markdown]
# ### Remove Non-Numeric Values from Numeric Fields

# %%
numeric = list(application_test.select_dtypes(include=[np.number]).columns.values)

# Apply the np.nan_to_num transformation
for feature in numeric: 
    application_train[feature] = make_numeric(application_train, feature)
    application_test[feature] = make_numeric(application_test, feature)

# %% [markdown]
# ### Scale Numeric Fields

# %%
# Initialize a scaler, then apply it to the features
scaler = StandardScaler()

# Technique for selecting numeric fields from: 
# https://stackoverflow.com/questions/25039626/how-do-i-find-numeric-columns-in-pandas
numeric = list(application_test.select_dtypes(include=[np.number]).columns.values)

scaler = scaler.fit(application_train)

# %%
application_train[numeric] = scaler.transform(application_train[numeric])
application_test[numeric] = scaler.transform(application_test[numeric])

# %% [markdown]
# ### Preview
# Show our transformed dataset

# %%
# Show an example of a record with scaling applied
display(application_train.head(n = 5))
# Out:
#    AMT_ANNUITY  AMT_CREDIT  AMT_GOODS_PRICE  AMT_INCOME_TOTAL  \
# 0    -0.166065   -0.478095        -0.505662          0.142129
# 1     0.592710    1.725450         1.600480          0.426792
# 2    -1.404507   -1.152888        -1.090025         -0.427196
# 3     0.177929   -0.711430        -0.651753         -0.142533
# 4    -0.361658   -0.213734        -0.067390         -0.199466
#
#    AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_HOUR  \
# 0
# 3       -0.524829       -0.522462                          0.650984
# 4       -0.524829       -0.522462                          0.650984
#
#    FONDKAPREMONT_MODE_org spec account  FONDKAPREMONT_MODE_reg oper account  \
# 0                            -0.136428                             1.779079
# 1                            -0.136428                             1.779079
# 2                            -0.136428                            -0.562089
# 3                            -0.136428                            -0.562089
# 4                            -0.136428                            -0.562089
#
#    FONDKAPREMONT_MODE_reg oper spec account  HOUR_APPR_PROCESS_START_0  \
# 0                                 -0.202211                  -0.011406
# 1                                 -0.202211                  -0.011406
# 2                                 -0.202211                  -0.011406
# 3                                 -0.202211                  -0.011406
# 4                                 -0.202211                  -0.011406
#
#    HOUR_APPR_PROCESS_START_1  HOUR_APPR_PROCESS_START_10  \
# 0                  -0.016726                    2.674329
# 1                  -0.016726                   -0.373926
# 2                  -0.016726                   -0.373926
# 3                  -0.016726                   -0.373926
# 4                  -0.016726                   -0.373926
#
#    HOUR_APPR_PROCESS_START_11  HOUR_APPR_PROCESS_START_12  \
# 0                   -0.371135                   -0.353932
# 1                    2.694436                   -0.353932
# 2                   -0.371135                   -0.353932
# 3                   -0.371135                   -0.353932
# 4                    2.694436                   -0.353932
#
#    HOUR_APPR_PROCESS_START_13  HOUR_APPR_PROCESS_START_14  \
# 0                   -0.334584                   -0.314523
# 1                   -0.334584                   -0.314523
# 2                   -0.334584                   -0.314523
# 3                   -0.334584                   -0.314523
# 4                   -0.334584                   -0.314523
#
#    HOUR_APPR_PROCESS_START_15  HOUR_APPR_PROCESS_START_16  \
# 0                   -0.296432                   -0.266452
# 1                   -0.296432                   -0.266452
# 2                   -0.296432                   -0.266452
# 3                   -0.296432                   -0.266452
# 4                   -0.296432                   -0.266452
#
#    HOUR_APPR_PROCESS_START_17  HOUR_APPR_PROCESS_START_18  \
# 0                   -0.225656                   -0.174123
# 1                   -0.225656                   -0.174123
# 2                   -0.225656                   -0.174123
# 3                    4.431515                   -0.174123
# 4                   -0.225656                   -0.174123
#
#    HOUR_APPR_PROCESS_START_19  HOUR_APPR_PROCESS_START_2  \
# 0                    -0.11257                  -0.031509
# 1                    -0.11257                  -0.031509
# 2                    -0.11257                  -0.031509
# 3                    -0.11257                  -0.031509
# 4                    -0.11257                  -0.031509
#
#    HOUR_APPR_PROCESS_START_20  HOUR_APPR_PROCESS_START_21  \
# 0                   -0.062486                   -0.036315
# 1                   -0.062486                   -0.036315
# 2                   -0.062486                   -0.036315
# 3                   -0.062486                   -0.036315
# 4                   -0.062486                   -0.036315
#
#    HOUR_APPR_PROCESS_START_22  HOUR_APPR_PROCESS_START_23  \
# 0                   -0.022091                   -0.011548
# 1                   -0.022091                   -0.011548
# 2                   -0.022091                   -0.011548
# 3                   -0.022091                   -0.011548
# 4                   -0.022091                   -0.011548
#
#    HOUR_APPR_PROCESS_START_3  HOUR_APPR_PROCESS_START_4  \
# 0                  -0.063371                  -0.082723
# 1                  -0.063371                  -0.082723
# 2                  -0.063371                  -0.082723
# 3                  -0.063371                  -0.082723
# 4                  -0.063371                  -0.082723
#
#    HOUR_APPR_PROCESS_START_5  HOUR_APPR_PROCESS_START_6  \
# 0                  -0.109417                   -0.13916
# 1                  -0.109417                   -0.13916
# 2                  -0.109417                   -0.13916
# 3                  -0.109417                   -0.13916
# 4                  -0.109417                   -0.13916
#
#    HOUR_APPR_PROCESS_START_7  HOUR_APPR_PROCESS_START_8  \
# 0                  -0.174934                  -0.227457
# 1                  -0.174934                  -0.227457
# 2                  -0.174934                  -0.227457
# 3                  -0.174934                  -0.227457
# 4                  -0.174934                  -0.227457
#
#    HOUR_APPR_PROCESS_START_9  HOUSETYPE_MODE_not specified  \
# 0                  -0.312659                     -1.536135
# 1                  -0.312659                     -1.536135
# 2                   3.198372                      0.650984
# 3                  -0.312659                      0.650984
# 4                  -0.312659                      0.650984
#
#    HOUSETYPE_MODE_org spec account  HOUSETYPE_MODE_reg oper account  \
# 0                        -0.136428                         1.779079
# 1                        -0.136428                         1.779079
# 2                        -0.136428                        -0.562089
# 3                        -0.136428                        -0.562089
# 4                        -0.136428                        -0.562089
#
#    HOUSETYPE_MODE_reg oper spec account  LANDAREA_AVG  LANDAREA_MEDI  \
# 0                             -0.202211      0.162782       0.165022
# 1                             -0.202211     -0.228092      -0.227585
# 2                             -0.202211     -0.440702      -0.440853
# 3                             -0.202211     -0.440702      -0.440853
# 4                             -0.202211     -0.440702      -0.440853
#
#    LANDAREA_MODE  LIVE_CITY_NOT_WORK_CITY  LIVE_REGION_NOT_WORK_REGION  \
# 0       0.185154                -0.467814                    -0.205869
# 1      -0.222405                -0.467814                    -0.205869
# 2      -0.431913                -0.467814                    -0.205869
# 3      -0.431913                -0.467814                    -0.205869
# 4      -0.431913                 2.137601                    -0.205869
#
#    LIVINGAPARTMENTS_AVG  LIVINGAPARTMENTS_MEDI  LIVINGAPARTMENTS_MODE  \
# 0             -0.166853              -0.165974              -0.154904
# 1              0.648129               0.655182               0.617489
# 2             -0.455166              -0.455213              -0.453020
# 3             -0.455166              -0.455213              -0.453020
# 4             -0.455166              -0.455213              -0.453020
#
#    LIVINGAREA_AVG  LIVINGAREA_MEDI  LIVINGAREA_MODE  \
# 0       -0.364140        -0.362243        -0.346934
# 1        0.014866         0.017768         0.027531
# 2       -0.564727        -0.563180        -0.555204
# 3       -0.564727        -0.563180        -0.555204
# 4       -0.564727        -0.563180        -0.555204
#
#    NAME_CONTRACT_TYPE_Cash loans  NAME_CONTRACT_TYPE_Revolving loans  \
# 0                       0.324395                           -0.324395
# 1                       0.324395                           -0.324395
# 2                      -3.082659                            3.082659
# 3                       0.324395                           -0.324395
# 4                       0.324395                           -0.324395
#
#    NAME_EDUCATION_TYPE_Academic degree  NAME_EDUCATION_TYPE_Higher education  \
# 0                              -0.0231                             -0.567262
# 1                              -0.0231                              1.762853
# 2                              -0.0231                             -0.567262
# 3                              -0.0231                             -0.567262
# 4                              -0.0231                             -0.567262
#
#    NAME_EDUCATION_TYPE_Incomplete higher  NAME_EDUCATION_TYPE_Lower secondary  \
# 0                              -0.185945                            -0.112095
# 1                              -0.185945                            -0.112095
# 2                              -0.185945                            -0.112095
# 3                              -0.185945                            -0.112095
# 4                              -0.185945                            -0.112095
#
#    NAME_EDUCATION_TYPE_Secondary / secondary special  \
# 0                                           0.638808
# 1                                          -1.565416
# 2                                           0.638808
# 3                                           0.638808
# 4                                           0.638808
#
#    NAME_FAMILY_STATUS_Civil marriage  NAME_FAMILY_STATUS_Married  \
# 0                          -0.327423                   -1.329812
# 1                          -0.327423                    0.751986
# 2                          -0.327423                   -1.329812
# 3                           3.054149                   -1.329812
# 4                          -0.327423                   -1.329812
#
#    NAME_FAMILY_STATUS_Separated  NAME_FAMILY_STATUS_Single / not married  \
# 0                     -0.262121                                 2.401419
# 1                     -0.262121                                -0.416421
# 2                     -0.262121                                 2.401419
# 3                     -0.262121                                -0.416421
# 4                     -0.262121                                 2.401419
#
#    NAME_FAMILY_STATUS_Unknown  NAME_FAMILY_STATUS_Widow  \
# 0                    -0.00255                 -0.234957
# 1                    -0.00255                 -0.234957
# 2                    -0.00255                 -0.234957
# 3                    -0.00255                 -0.234957
# 4                    -0.00255                 -0.234957
#
#    NAME_HOUSING_TYPE_Co-op apartment  NAME_HOUSING_TYPE_House / apartment  \
# 0                          -0.060515                             0.356313
# 1                          -0.060515                             0.356313
# 2                          -0.060515                             0.356313
# 3                          -0.060515                             0.356313
# 4                          -0.060515                             0.356313
#
#    NAME_HOUSING_TYPE_Municipal apartment  NAME_HOUSING_TYPE_Office apartment  \
# 0                              -0.194264                           -0.092646
# 1                              -0.194264                           -0.092646
# 2                              -0.194264                           -0.092646
# 3                              -0.194264                           -0.092646
# 4                              -0.194264                           -0.092646
#
#    NAME_HOUSING_TYPE_Rented apartment  NAME_HOUSING_TYPE_With parents  \
# 0                           -0.126998                       -0.225179
# 1                           -0.126998                       -0.225179
# 2                           -0.126998                       -0.225179
# 3                           -0.126998                       -0.225179
# 4                           -0.126998                       -0.225179
#
#    NAME_INCOME_TYPE_Businessman  NAME_INCOME_TYPE_Commercial associate  \
# 0                     -0.005703                              -0.550997
# 1                     -0.005703                              -0.550997
# 2                     -0.005703                              -0.550997
# 3                     -0.005703                              -0.550997
# 4                     -0.005703                              -0.550997
#
#    NAME_INCOME_TYPE_Maternity leave  NAME_INCOME_TYPE_Pensioner  \
# 0                         -0.004032                   -0.468573
# 1                         -0.004032                   -0.468573
# 2                         -0.004032                   -0.468573
# 3                         -0.004032                   -0.468573
# 4                         -0.004032                   -0.468573
#
#    NAME_INCOME_TYPE_State servant  NAME_INCOME_TYPE_Student  \
# 0                       -0.275564                 -0.007651
# 1                        3.628919                 -0.007651
# 2                       -0.275564                 -0.007651
# 3                       -0.275564                 -0.007651
# 4                       -0.275564                 -0.007651
#
#    NAME_INCOME_TYPE_Unemployed  NAME_INCOME_TYPE_Working  \
# 0                    -0.008459                  0.967876
# 1                    -0.008459                 -1.033190
# 2                    -0.008459                  0.967876
# 3                    -0.008459                  0.967876
# 4                    -0.008459                  0.967876
#
#    NAME_TYPE_SUITE_Children  NAME_TYPE_SUITE_Family  \
# 0                 -0.103625               -0.387514
# 1                 -0.103625                2.580551
# 2                 -0.103625               -0.387514
# 3                 -0.103625               -0.387514
# 4                 -0.103625               -0.387514
#
#    NAME_TYPE_SUITE_Group of people  NAME_TYPE_SUITE_Other_A  \
# 0                        -0.029699                -0.053142
# 1                        -0.029699                -0.053142
# 2                        -0.029699                -0.053142
# 3                        -0.029699                -0.053142
# 4                        -0.029699                -0.053142
#
#    NAME_TYPE_SUITE_Other_B  NAME_TYPE_SUITE_Spouse, partner  \
# 0                -0.076087                        -0.195944
# 1                -0.076087                        -0.195944
# 2                -0.076087                        -0.195944
# 3                -0.076087                        -0.195944
# 4                -0.076087                        -0.195944
#
#    NAME_TYPE_SUITE_Unaccompanied  NONLIVINGAPARTMENTS_AVG  \
# 0                       0.487175                -0.100846
# 1                      -2.052651                 0.045223
# 2                       0.487175                -0.100846
# 3                       0.487175                -0.100846
# 4                       0.487175                -0.100846
#
#    NONLIVINGAPARTMENTS_MEDI  NONLIVINGAPARTMENTS_MODE  NONLIVINGAREA_AVG  \
# 0                 -0.099729                 -0.095487          -0.261343
# 1                  0.047355                 -0.095487          -0.059838
# 2                 -0.099729                 -0.095487          -0.261343
# 3                 -0.099729                 -0.095487          -0.261343
# 4                 -0.099729                 -0.095487          -0.261343
#
#    NONLIVINGAREA_MEDI  NONLIVINGAREA_MODE  OBS_30_CNT_SOCIAL_CIRCLE  \
# 0           -0.258124           -0.247602                  0.242861
# 1           -0.054163           -0.247602                 -0.174085
# 2           -0.258124           -0.247602                 -0.591031
# 3           -0.258124           -0.247602                  0.242861
# 4           -0.258124           -0.247602                 -0.591031
#
#    OBS_60_CNT_SOCIAL_CIRCLE  OCCUPATION_TYPE_Accountants  \
# 0                  0.252132                    -0.181557
# 1                 -0.168527                    -0.181557
# 2                 -0.589187                    -0.181557
# 3                  0.252132                    -0.181557
# 4                 -0.589187                    -0.181557
#
#    OCCUPATION_TYPE_Cleaning staff  OCCUPATION_TYPE_Cooking staff  \
# 0                        -0.12395                      -0.140418
# 1                        -0.12395                      -0.140418
# 2                        -0.12395                      -0.140418
# 3                        -0.12395                      -0.140418
# 4                        -0.12395                      -0.140418
#
#    OCCUPATION_TYPE_Core staff  OCCUPATION_TYPE_Drivers  \
# 0                   -0.313823                -0.253753
# 1                    3.186507                -0.253753
# 2                   -0.313823                -0.253753
# 3                   -0.313823                -0.253753
# 4                    3.186507                -0.253753
#
#    OCCUPATION_TYPE_HR staff  OCCUPATION_TYPE_High skill tech staff  \
# 0                 -0.042827                              -0.196033
# 1                 -0.042827                              -0.196033
# 2                 -0.042827                              -0.196033
# 3                 -0.042827                              -0.196033
# 4                 -0.042827                              -0.196033
#
#    OCCUPATION_TYPE_IT staff  OCCUPATION_TYPE_Laborers  \
# 0                 -0.041394                  2.138285
# 1                 -0.041394                 -0.467664
# 2                 -0.041394                  2.138285
# 3                 -0.041394                  2.138285
# 4                 -0.041394                 -0.467664
#
#    OCCUPATION_TYPE_Low-skill Laborers  OCCUPATION_TYPE_Managers  \
# 0                           -0.082782                  -0.27329
# 1                           -0.082782                  -0.27329
# 2                           -0.082782                  -0.27329
# 3                           -0.082782                  -0.27329
# 4                           -0.082782                  -0.27329
#
#    OCCUPATION_TYPE_Medicine staff  OCCUPATION_TYPE_Private service staff  \
# 0                        -0.16898                              -0.093269
# 1                        -0.16898                              -0.093269
# 2                        -0.16898                              -0.093269
# 3                        -0.16898                              -0.093269
# 4                        -0.16898                              -0.093269
#
#    OCCUPATION_TYPE_Realty agents  OCCUPATION_TYPE_Sales staff  \
# 0                      -0.049479                    -0.341411
# 1                      -0.049479                    -0.341411
# 2                      -0.049479                    -0.341411
# 3                      -0.049479                    -0.341411
# 4                      -0.049479                    -0.341411
#
#    OCCUPATION_TYPE_Secretaries  OCCUPATION_TYPE_Security staff  \
# 0                    -0.065283                       -0.149481
# 1                    -0.065283                       -0.149481
# 2                    -0.065283                       -0.149481
# 3                    -0.065283                       -0.149481
# 4                    -0.065283                       -0.149481
#
#    OCCUPATION_TYPE_Waiters/barmen staff  ORGANIZATION_TYPE_Advertising  \
# 0                             -0.066354                      -0.037377
# 1                             -0.066354                      -0.037377
# 2                             -0.066354                      -0.037377
# 3                             -0.066354                      -0.037377
# 4                             -0.066354                      -0.037377
#
#    ORGANIZATION_TYPE_Agriculture  ORGANIZATION_TYPE_Bank  \
# 0                      -0.089691               -0.090662
# 1                      -0.089691               -0.090662
# 2                      -0.089691               -0.090662
# 3                      -0.089691               -0.090662
# 4                      -0.089691               -0.090662
#
#    ORGANIZATION_TYPE_Business Entity Type 1  \
# 0                                 -0.140875
# 1                                 -0.140875
# 2                                 -0.140875
# 3                                 -0.140875
# 4                                 -0.140875
#
#    ORGANIZATION_TYPE_Business Entity Type 2  \
# 0                                 -0.188513
# 1                                 -0.188513
# 2                                 -0.188513
# 3                                 -0.188513
# 4                                 -0.188513
#
#    ORGANIZATION_TYPE_Business Entity Type 3  ORGANIZATION_TYPE_Cleaning  \
# 0                                  1.876900                    -0.02909
# 1                                 -0.532794                    -0.02909
# 2                                 -0.532794                    -0.02909
# 3                                  1.876900                    -0.02909
# 4                                 -0.532794                    -0.02909
#
#    ORGANIZATION_TYPE_Construction  ORGANIZATION_TYPE_Culture  \
# 0                       -0.149481                  -0.035128
# 1                       -0.149481                  -0.035128
# 2                       -0.149481                  -0.035128
# 3                       -0.149481                  -0.035128
# 4                       -0.149481                  -0.035128
#
#    ORGANIZATION_TYPE_Electricity  ORGANIZATION_TYPE_Emergency  \
# 0                      -0.055668                    -0.042713
# 1                      -0.055668                    -0.042713
# 2                      -0.055668                    -0.042713
# 3                      -0.055668                    -0.042713
# 4                      -0.055668                    -0.042713
#
#    ORGANIZATION_TYPE_Government  ORGANIZATION_TYPE_Hotel  \
# 0                     -0.187130                -0.056136
# 1                     -0.187130                -0.056136
# 2                      5.343875                -0.056136
# 3                     -0.187130                -0.056136
# 4                     -0.187130                -0.056136
#
#    ORGANIZATION_TYPE_Housing  ORGANIZATION_TYPE_Industry: type 1  \
# 0
#
#    ORGANIZATION_TYPE_Trade: type 5  ORGANIZATION_TYPE_Trade: type 6  \
# 0                        -0.012624                        -0.045345
# 1                        -0.012624                        -0.045345
# 2                        -0.012624                        -0.045345
# 3                        -0.012624                        -0.045345
# 4                        -0.012624                        -0.045345
#
#    ORGANIZATION_TYPE_Trade: type 7  ORGANIZATION_TYPE_Transport: type 1  \
# 0                        -0.161651                            -0.025575
# 1                        -0.161651                            -0.025575
# 2                        -0.161651                            -0.025575
# 3                        -0.161651                            -0.025575
# 4                        -0.161651                            -0.025575
#
#    ORGANIZATION_TYPE_Transport: type 2  ORGANIZATION_TYPE_Transport: type 3  \
# 0                            -0.084964                            -0.062249
# 1                            -0.084964                            -0.062249
# 2                            -0.084964                            -0.062249
# 3                            -0.084964                            -0.062249
# 4                            -0.084964                            -0.062249
#
#    ORGANIZATION_TYPE_Transport: type 4  ORGANIZATION_TYPE_University  \
# 0                            -0.133669                     -0.065833
# 1                            -0.133669                     -0.065833
# 2                            -0.133669                     -0.065833
# 3                            -0.133669                     -0.065833
# 4                            -0.133669                     -0.065833
#
#    ORGANIZATION_TYPE_XNA  OWN_CAR_AGE  REGION_POPULATION_RELATIVE  \
# 0              -0.468635    -0.455284                   -0.149452
# 1              -0.468635    -0.455284                   -1.252750
# 2              -0.468635     2.430559                   -0.783451
# 3              -0.468635    -0.455284                   -0.928991
# 4              -0.468635    -0.455284                    0.563570
#
#    REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  REG_CITY_NOT_LIVE_CITY  \
# 0             -0.103064                    -0.062699               -0.291208
# 1             -2.067573                    -2.051813               -0.291208
# 2             -0.103064                    -0.062699               -0.291208
# 3             -0.103064                    -0.062699               -0.291208
# 4             -0.103064                    -0.062699               -0.291208
#
#    REG_CITY_NOT_WORK_CITY  REG_REGION_NOT_LIVE_REGION  \
# 0               -0.547236                   -0.124004
# 1               -0.547236                   -0.124004
# 2               -0.547236                   -0.124004
# 3               -0.547236                   -0.124004
# 4                1.827367                   -0.124004
#
#    REG_REGION_NOT_WORK_REGION  TOTALAREA_MODE  WALLSMATERIAL_MODE_Block  \
# 0                   -0.231267       -0.411375                 -0.176135
# 1                   -0.231267        0.197887                  5.677469
# 2                   -0.231267       -0.572048                 -0.176135
# 3                   -0.231267       -0.572048                 -0.176135
# 4                   -0.231267       -0.572048                 -0.176135
#
#    WALLSMATERIAL_MODE_Mixed  WALLSMATERIAL_MODE_Monolithic  \
# 0                 -0.086733                      -0.076281
# 1                 -0.086733                      -0.076281
# 2                 -0.086733                      -0.076281
# 3                 -0.086733                      -0.076281
# 4                 -0.086733                      -0.076281
#
#    WALLSMATERIAL_MODE_Others  WALLSMATERIAL_MODE_Panel  \
# 0                  -0.072886                 -0.522963
# 1                  -0.072886                 -0.522963
# 2                  -0.072886                 -0.522963
# 3                  -0.072886                 -0.522963
# 4                  -0.072886                 -0.522963
#
#    WALLSMATERIAL_MODE_Stone, brick  WALLSMATERIAL_MODE_Wooden  \
# 0                         1.935056                  -0.133215
# 1                        -0.516781                  -0.133215
# 2                        -0.516781                  -0.133215
# 3                        -0.516781                  -0.133215
# 4                        -0.516781                  -0.133215
#
#    WALLSMATERIAL_MODE_not specified  WEEKDAY_APPR_PROCESS_START_FRIDAY  \
# 0                         -1.016959                          -0.442421
# 1                         -1.016959                          -0.442421
# 2                          0.983323                          -0.442421
# 3                          0.983323                          -0.442421
# 4                          0.983323                          -0.442421
#
#    WEEKDAY_APPR_PROCESS_START_MONDAY  WEEKDAY_APPR_PROCESS_START_SATURDAY  \
# 0                          -0.444395                            -0.351712
# 1                           2.250251                            -0.351712
# 2                           2.250251                            -0.351712
# 3                          -0.444395                            -0.351712
# 4                          -0.444395                            -0.351712
#
#    WEEKDAY_APPR_PROCESS_START_SUNDAY  WEEKDAY_APPR_PROCESS_START_THURSDAY  \
# 0                          -0.235673                            -0.443749
# 1                          -0.235673                            -0.443749
# 2                          -0.235673                            -0.443749
# 3                          -0.235673                            -0.443749
# 4                          -0.235673                             2.253525
#
#    WEEKDAY_APPR_PROCESS_START_TUESDAY  WEEKDAY_APPR_PROCESS_START_WEDNESDAY  \
# 0                           -0.461015                              2.218375
# 1                           -0.461015                             -0.450780
# 2                           -0.461015                             -0.450780
# 3                           -0.461015                              2.218375
# 4                           -0.461015                             -0.450780
#
#    YEARS_BEGINEXPLUATATION_AVG  YEARS_BEGINEXPLUATATION_MEDI  \
# 0                     0.960978                      0.960861
# 1                     0.987275                      0.987155
# 2                    -1.020852                     -1.020765
# 3                    -1.020852                     -1.020765
# 4                    -1.020852                     -1.020765
#
#    YEARS_BEGINEXPLUATATION_MODE  YEARS_BUILD_AVG  YEARS_BUILD_MEDI  \
# 0                      0.961652         1.016443          1.023576
# 1                      0.987948         1.505968          1.504599
# 2                     -1.020127        -0.698001         -0.698343
# 3                     -1.020127        -0.698001         -0.698343
# 4                     -1.020127        -0.698001         -0.698343
#
#    YEARS_BUILD_MODE  PER_CREDIT_INCOME  PER_GOODS_CREDIT  PER_ANNUITY_INCOME  \
# 0          1.042389           0.159961          0.018189            0.141793
# 1          1.508933          -0.174450         -0.168532            0.276183
# 2         -0.698841           0.072629          0.003323            0.082723
# 3         -0.698841           0.091853          0.004154            0.039259
# 4         -0.698841           0.046191         -0.010885            0.063702
#
#    NUM_BUREAU_REPORTS  SUM_BUREAU_BALANCES  SUM_CREDIT_CURRENCY_CODE_0  \
# 0            1.760329             0.546811                    1.763811
# 1           -0.476245            -0.420349                   -0.476383
# 2           -0.476245            -0.420349                   -0.476383
# 3           -0.476245            -0.420349                   -0.476383
# 4           -0.476245            -0.420349                   -0.476383
#
#    SUM_CREDIT_CURRENCY_CODE_1  SUM_CREDIT_CURRENCY_CODE_2  \
# 0                   -0.024437                   -0.010391
# 1                   -0.024437                   -0.010391
# 2                   -0.024437                   -0.010391
# 3                   -0.024437                   -0.010391
# 4                   -0.024437                   -0.010391
#
#    SUM_CREDIT_CURRENCY_CODE_3  SUM_CREDIT_ACTIVE_CODE_0  \
# 0                    -0.00255                  0.996753
# 1                    -0.00255                 -0.457098
# 2                    -0.00255                 -0.457098
# 3                    -0.00255                 -0.457098
# 4                    -0.00255                 -0.457098
#
#    SUM_CREDIT_ACTIVE_CODE_1  SUM_CREDIT_ACTIVE_CODE_2  \
# 0                  -0.00255                  1.968236
# 1                  -0.00255                 -0.425688
# 2                  -0.00255                 -0.425688
# 3                  -0.00255                 -0.425688
# 4                  -0.00255                 -0.425688
#
#    SUM_CREDIT_ACTIVE_CODE_3  SUM_CREDIT_TYPE_CODE_0  SUM_CREDIT_TYPE_CODE_1  \
# 0                 -0.075635               -0.028102               -0.138733
# 1                 -0.075635               -0.028102               -0.138733
# 2                 -0.075635               -0.028102               -0.138733
# 3                 -0.075635               -0.028102               -0.138733
# 4                 -0.075635               -0.028102               -0.138733
#
#    SUM_CREDIT_TYPE_CODE_2  SUM_CREDIT_TYPE_CODE_3  SUM_CREDIT_TYPE_CODE_4  \
# 0               -0.007702                1.012598                3.520264
# 1               -0.007702               -0.455496               -0.386883
# 2               -0.007702               -0.455496               -0.386883
# 3               -0.007702               -0.455496               -0.386883
# 4               -0.007702               -0.455496               -0.386883
#
#    SUM_CREDIT_TYPE_CODE_5  SUM_CREDIT_TYPE_CODE_6  SUM_CREDIT_TYPE_CODE_7  \
# 0                     0.0               -0.033562               -0.001803
# 1                     0.0               -0.033562               -0.001803
# 2                     0.0               -0.033562               -0.001803
# 3                     0.0               -0.033562               -0.001803
# 4                     0.0               -0.033562               -0.001803
#
#    SUM_CREDIT_TYPE_CODE_8  SUM_CREDIT_TYPE_CODE_9  SUM_CREDIT_TYPE_CODE_10  \
# 0               -0.003825               -0.022737                -0.043898
# 1               -0.003825               -0.022737                -0.043898
# 2               -0.003825               -0.022737                -0.043898
# 3               -0.003825               -0.022737                -0.043898
# 4               -0.003825               -0.022737                -0.043898
#
#    SUM_CREDIT_TYPE_CODE_11  SUM_CREDIT_TYPE_CODE_12  SUM_CREDIT_TYPE_CODE_13  \
# 0                -0.001803                -0.124818                -0.004771
# 1                -0.001803                -0.124818                -0.004771
# 2                -0.001803                -0.124818                -0.004771
# 3                -0.001803                -0.124818                -0.004771
# 4                -0.001803                -0.124818                -0.004771
#
#    SUM_CREDIT_TYPE_CODE_14  SUM_STATUS_0  SUM_STATUS_1  SUM_STATUS_2  \
# 0                -0.019285      0.812763       9.24113     -0.090937
# 1                -0.019285     -0.406781      -0.17618     -0.090937
# 2                -0.019285     -0.406781      -0.17618     -0.090937
# 3                -0.019285     -0.406781      -0.17618     -0.090937
# 4                -0.019285     -0.406781      -0.17618     -0.090937
#
#    SUM_STATUS_3  SUM_STATUS_4  SUM_STATUS_5  SUM_STATUS_C  SUM_STATUS_X  \
# 0     -0.066203     -0.059805     -0.046781      0.002266      0.169359
# 1     -0.066203     -0.059805     -0.046781     -0.352550     -0.270597
# 2     -0.066203     -0.059805     -0.046781     -0.352550     -0.270597
# 3     -0.066203     -0.059805     -0.046781     -0.352550     -0.270597
# 4     -0.066203     -0.059805     -0.046781     -0.352550     -0.270597
#
#    MED_DAYS_CREDIT  SUM_CREDIT_DAYS_OVERDUE  SUM_DAYS_CREDIT_ENDDATE  \
# 0        -1.286057                -0.024989                -0.000598
# 1         0.535600                -0.024989                -0.292165
# 2         0.535600                -0.024989                -0.292165
# 3         0.535600                -0.024989                -0.292165
# 4         0.535600                -0.024989                -0.292165
#
#    SUM_DAYS_ENDDATE_FACT  SUM_AMT_CREDIT_MAX_OVERDUE  SUM_CNT_CREDIT_PROLONG  \
# 0               1.152029                    0.021912               -0.089078
# 1              -0.387237                   -0.008890               -0.089078
# 2              -0.387237                   -0.008890               -0.089078
# 3              -0.387237                   -0.008890               -0.089078
# 4              -0.387237                   -0.008890               -0.089078
#
#    SUM_AMT_CREDIT_SUM  SUM_AMT_CREDIT_SUM_DEBT  SUM_AMT_CREDIT_SUM_LIMIT  \
# 0            0.102418                 0.032617                  0.525573
# 1           -0.267807                -0.193505                 -0.119904
# 2           -0.267807                -0.193505                 -0.119904
# 3           -0.267807                -0.193505                 -0.119904
# 4           -0.267807                -0.193505                 -0.119904
#
#    SUM_DAYS_CREDIT_UPDATE
# 0                1.261514
# 1               -0.389860
# 2               -0.389860
# 3               -0.389860
# 4               -0.389860

# %% [markdown]
# ### Output
# Save out our preprocessed data to temporary intermediate files

# %%
application_train['SK_ID_CURR'] = application_train_SK_ID_CURR
application_train['TARGET'] = target_train
application_test['SK_ID_CURR'] = application_test_SK_ID_CURR

application_train.to_csv('data/tmp/bureau_application_train_preprocessed.csv')
application_test.to_csv('data/tmp/bureau_application_train_preprocessed.csv')
